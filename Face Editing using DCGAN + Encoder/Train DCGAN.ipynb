jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
import numpy as np 
from glob import glob
import random
from PIL import Image 
import os

# %%
from keras.preprocessing.image import save_img
from keras.preprocessing.image import array_to_img

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ##Class Definition of DCGAN as presented in paper by Radford et. al.

# %% [markdown]
# ####The Model Architecture of Generator of DCGAN (Deep Convolutional GAN) as discussed in the Original Paper
# ####But we are using a slightly different Architecture from the original one

# %% [markdown]
# ![1_rdXKdyfNjorzP10ZA3yNmQ.png](data:image/png;base64,...)

# %% [markdown]
# ####The model Architecture of Discriminator of DCGAN as discussed in original paper is follwing
# ####But we are using a slightly different Architecture as compared to original paper

# %% [markdown]
# ![dcgan_discriminator.png](data:image/png;base64,...)

# %% [markdown]
# ####Working of DCGAN

# %% [markdown]
# ![1_eB7mfnfoAfZCZ-bOr7SImQ.jpeg](data:image/jpeg;base64,...)

# %%
class DCGAN:
    
    def __init__(self, input_shape, z_dim, lr_rate, beta1=0.5, alpha=0.2):

        # Initialising the variables
        self.lr_rate = tf.Variable(lr_rate, trainable=False)
        self.input_shape = input_shape
        self.z_dim = z_dim

        # Calling the model_io function
        self.input_real, self.input_z = self.model_io(self.input_shape,self.z_dim)
        
        # Calling the model_loss fucntion
        self.disc_loss, self.gen_loss, self.output_gen = self.model_loss(self.input_real, self.input_z, self.input_shape[2])  

        # Calling the model_opti function     
        self.disc_opt, self.gen_opt = self.model_opti(self.disc_loss, self.gen_loss, self.lr_rate, beta1)

     
   
    """    
    Function to model placeholders for input of both generator and discriminator
    """     
    def model_io(self, input_shape, z_dim):

        inputs_real = tf.placeholder(tf.float32, shape=(None, input_shape[0], input_shape[1], input_shape[2]), name="input_real")
        inputs_z = tf.placeholder(tf.float32, shape=(None, z_dim), name="input_z")

        return inputs_real,inputs_z   



    """
    Generator Architecture
    """
    def generator(self, z, out_channel_dim, is_train=True):

        # Intialising the weights with mean = 0 and stddev = 0.02
        w_init = tf.random_normal_initializer(mean=0.0, stddev = 0.02)

        with tf.variable_scope('generator', reuse= False if is_train==True else True):
            
            x1 = tf.reshape(z,(-1,1,1,100))
            
            # Adding the first Deconv layer 
            # 512 filters of 4x4 (kernel = 4) with stride = 1
            deconv1 = tf.layers.conv2d_transpose(x1, 512, 4, 1, padding='VALID', kernel_initializer=w_init)
            # Applying the Spatial Batch Normalisation layer
            bn_norm1 = tf.layers.batch_normalization(deconv1, training=is_train)
            # Applying the ReLu function
            relu1 = tf.nn.relu(bn_norm1)
            
            # Adding the second Deconv layer 
            # 256 filters of 4x4 (kernel = 4) with stride = 2
            deconv2 = tf.layers.conv2d_transpose(relu1, 256, 4, 2, padding='SAME', kernel_initializer=w_init)
            bn_norm2 = tf.layers.batch_normalization(deconv2, training=is_train)
            relu2 = tf.nn.relu(bn_norm2)
            
            # Adding the third Deconv layer 
            # 128 filters of 4x4 (kernel = 4) with stride = 2
            deconv3 = tf.layers.conv2d_transpose(relu2, 128, 4, 2, padding='SAME', kernel_initializer=w_init)
            bn_norm3 = tf.layers.batch_normalization(deconv3, training=is_train)
            relu3 = tf.nn.relu(bn_norm3)
            
            # Adding the fourth Deconv layer 
            # 64 filters of 4x4 (kernel = 4) with stride = 2
            deconv4 = tf.layers.conv2d_transpose(relu3, 64, 4, 2, padding='SAME', kernel_initializer=w_init)
            bn_norm4 = tf.layers.batch_normalization(deconv4, training=is_train)
            relu4 = tf.nn.relu(bn_norm4)
            
            # Adding the fifth Deconv layer 
            # output dimension filters of 4x4 (kernel = 4) with stride = 2
            deconv5 = tf.layers.conv2d_transpose(relu4, out_channel_dim, 4, 2, padding='SAME', kernel_initializer=w_init)
            
            logits = deconv5
            out = tf.tanh(deconv5, name="generator_out")
            
            return out, logits  

  

    
    """
    Discriminator Architecture

    Architecture is similar as described in the photo above
    """
    def discriminator(self, images, alpha=0.2, reuse = False):

       # Initialising the weights
       w_init = tf.random_normal_initializer(mean=0.0, stddev=0.02)

       with tf.variable_scope('discriminator',reuse=reuse):
           
           # Adding the first Conv layer
           # 64 filters of 4x4 (kernel = 4) with stride = 2
           conv1 = tf.layers.conv2d(images, 64, 4, 2, padding='SAME', kernel_initializer=w_init)
           # Applying LeakyReLu fucntion
           lrelu1 = tf.nn.leaky_relu(conv1, alpha=alpha)
           
           # Adding the second Conv layer
           # 128 filters of 4x4 (kernel = 4) with stride = 2
           conv2 = tf.layers.conv2d(lrelu1, 128, 4, 2, padding='SAME', kernel_initializer=w_init)
           bn_norm1 = tf.layers.batch_normalization(conv2, training=True)
           lrelu2 = tf.nn.leaky_relu(bn_norm1, alpha=alpha)
           
           # Adding the third Conv layer
           # 256 filters of 4x4 (kernel = 4) with stride = 2
           conv3 = tf.layers.conv2d(lrelu2, 256, 4, 2, padding='SAME', kernel_initializer=w_init)
           bn_norm2 = tf.layers.batch_normalization(conv3, training=True)
           lrelu3 = tf.nn.leaky_relu(bn_norm2, alpha=alpha)
           
           # Adding the fourth Conv layer
           # 512 filters of 4x4 (kernel = 4) with stride = 2
           conv4 = tf.layers.conv2d(lrelu3, 512, 4, 2, padding='SAME', kernel_initializer=w_init)
           bn_norm3 = tf.layers.batch_normalization(conv4, training=True)
           lrelu4 = tf.nn.leaky_relu(bn_norm3, alpha=alpha)
           
           # Adding the fifth Conv layer
           # 512 filters of 4x4 (kernel = 4) with stride = 2
           conv5 = tf.layers.conv2d(lrelu4, 512, 4, 2, padding='SAME', kernel_initializer=w_init)
           
           flat = tf.reshape(conv5,(-1,512))
           
           # Adding a Dense Layer 
           logits = tf.layers.dense(flat, 1, kernel_initializer=w_init)
           
           out = tf.sigmoid(logits, name="discriminator_out")
           
           return out, logits


    """
    Function to model the loss for both generator and discriminator. Returns the generated image.
    """       
    def model_loss(self, input_real, input_z, out_channel_dim):
        
        """
        Images from the dataset are labelled with label = 0.9 for better training
        """	
        label_smooth = 0.9 
        
        # get output of generator
        gen_img, gen_logits = self.generator(input_z, out_channel_dim, True)

        # pass real image to dicriminator
        disc_model_real, disc_logits_real = self.discriminator(input_real)
	
        # pass generated image to dicriminator
        disc_model_fake, disc_logits_fake = self.discriminator(gen_img,reuse=True)
            
        # calculating losses of Discriminator
        disc_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_logits_real, labels=label_smooth*tf.ones_like(disc_model_real))) 
        disc_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_logits_fake, labels=tf.zeros_like(disc_model_fake)))
        

        """
        Loss for discriminator is sum of loss for real image and fake image 
        """	
        disc_loss = disc_loss_real + disc_loss_fake
        

        """
        To find loss for generator, fake image is passed with label= real (0.9)
        """
        gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_logits_fake, labels=label_smooth*tf.ones_like(disc_model_fake)))
        
        return disc_loss, gen_loss, gen_img




    """
    Train generator and dicriminator using Adam Optimizer and optimise their weights
    """ 
    def model_opti(self,disc_loss,gen_loss,lr_rate,beta1):
        
        train_vars = tf.trainable_variables()

        # Separating the variables of Generator and Discriminator
        disc_vars = [var for var in train_vars if var.name.startswith('discriminator')]
        gen_vars = [var for var in train_vars if var.name.startswith('generator')]
        
        with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):

            # Optimise the weights by minimising loss by changing the var_list variables
            disc_train_opt = tf.train.AdamOptimizer(lr_rate, beta1=beta1).minimize(disc_loss, var_list = disc_vars)
            gen_train_opt = tf.train.AdamOptimizer(lr_rate, beta1=beta1).minimize(gen_loss, var_list=gen_vars)
        
        return disc_train_opt, gen_train_opt

# %% [markdown]
# ###Training the Model

# %%
"""
Function to get image from path and rescale them to [-1,1]
"""
def get_image_new(image_path, width, height):

    image = Image.open(image_path)

    #crop image to reduce clutter 
    image = image.crop((30,40,168,178))

    #Resizing image to smaller size -- 64 x 64 generally
    # Image.BILINEAR is for 2x2 linear interpolation  
    image = image.resize([width,height], Image.BILINEAR)

    # Normalisation steps
    image = np.array(image,dtype=np.float32)	
    image = np.divide(image,255)
    image = np.subtract(image,0.5)

    #scaling image to [-1,1]
    image = np.multiply(image,2)
    
    return image

# %%
def train(net, max_iter, batch_size, data_files, model_dir, image_dir, lr_rate, beta1, shape, z_dim, disc_loss, gen_loss):

    saver = tf.train.Saver(max_to_keep=None)
    
    random.shuffle(data_files)
    max_bs_len = int(len(data_files)/batch_size)*batch_size
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        #saver.restore(sess,model_dir+"try_5_3000\\")
        epoch = 0
        
        while epoch < (max_iter):
            bs = 0
            step = 0
            
            while bs < max_bs_len:
                # making batch of images
                batch_files = data_files[bs:(bs+batch_size)]
                # converting images to NumPy array using function get_image_new
                batch_images = np.array([get_image_new(sample_file, 64, 64) for sample_file in batch_files]).astype(np.float32) 
                
                batch_z = np.random.normal(loc=0.0, scale=1.0, size=(batch_size, z_dim))
                
                sess.run([net.disc_opt, net.gen_opt], feed_dict={net.input_real:batch_images, net.input_z:batch_z})
                
                if step % 100 == 0:
                    train_disc_loss = net.disc_loss.eval({net.input_real:batch_images,net.input_z:batch_z})
                    train_gen_loss = net.gen_loss.eval({net.input_real:batch_images,net.input_z:batch_z})
                    print ("Epoch = %r, Step = %r, disc_loss = %r , gen_loss = %r" % (epoch,step,train_disc_loss,train_gen_loss))
                    disc_loss.append(train_disc_loss)
                    gen_loss.append(train_gen_loss)

                if step % 200 == 0:
                    
                    example_z = np.random.uniform(-1,1,size=[1,z_dim])    
                    img = sess.run(net.output_gen,feed_dict={net.input_z:example_z})
                    img = np.reshape(img,(64,64,3))
                    
                    if np.array_equal(img.max(),img.min()) == False:
                        img = (((img - img.min())*255)/(img.max()-img.min())).astype(np.uint8)
                    else:
                        img = ((img - img.min())*255).astype(np.uint8)
                    
                    #scipy.misc.toimage(img, cmin=0.0, cmax=...).save(image_dir+"/img_"+str(epoch)+"_step_"+str(step)+".jpg")
                    sampled_img = array_to_img(img)
                    save_img(image_dir+"/img_"+str(epoch)+"_step_"+str(step)+".jpg", sampled_img)
                    
                #if step % 2 == 0:
                    #print ("step = %r" %(step))
                    
                bs = bs + batch_size
                step = step +1 
            
            if (epoch % 4 == 0):
                dir_path =  model_dir + "try_epoch_" + str(epoch)+"/"
                saver.save(sess, dir_path, write_meta_graph=True)
                print ("\n\n### Model Weights Saved Epoch = %r  ###\n\n" %(epoch))
                
            epoch = epoch + 1

    return disc_loss, gen_loss

# %%
data_path = '/content/img_celeba/' 
input_fname_pattern = "*.jpg"
model_dir = '/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/' 
sampled_images_dir = '/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_train_sampled_images'

# %%
batch_size = 64
z_dim = 100
lr_rate = 0.0002
beta1 = 0.5
alpha = 0.2
max_iter = 25

# CelebA Face Database is used in this project. 
data_files = glob(data_path+input_fname_pattern)

# Storing Losses
disc_loss = []
gen_loss = []

shape = 64,64,3
tf.reset_default_graph()

print(len(data_files))
# Out:
# 202599

# %% [markdown]
# ####Calling the functions required for Training

# %%
net = DCGAN(shape, z_dim, lr_rate, beta1, alpha)

disc_train_loss, gen_train_loss = train(net, max_iter, batch_size, data_files, model_dir, sampled_images_dir, lr_rate, beta1, shape, z_dim, disc_loss, gen_loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/convolutional.py:1294: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
#   warnings.warn('`tf.layers.conv2d_transpose` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/normalization.py:308: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   '`tf.layers.batch_normalization` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/convolutional.py:414: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# Epoch = 0, Step = 0, disc_loss = 0.95639676 , gen_loss = 1.1561269
# Epoch = 0, Step = 100, disc_loss = 0.4118312 , gen_loss = 3.084534
# Epoch = 0, Step = 200, disc_loss = 0.46059927 , gen_loss = 2.8924332
# Epoch = 0, Step = 300, disc_loss = 0.67061985 , gen_loss = 1.560494
# Epoch = 0, Step = 400, disc_loss = 0.69573855 , gen_loss = 1.5568088
# Epoch = 0, Step = 500, disc_loss = 0.964571 , gen_loss = 4.2766237
# Epoch = 0, Step = 600, disc_loss = 0.7028261 , gen_loss = 2.5503857
# Epoch = 0, Step = 700, disc_loss = 0.6188289 , gen_loss = 2.0094056
# Epoch = 0, Step = 800, disc_loss = 0.78574055 , gen_loss = 1.2422367
# Epoch = 0, Step = 900, disc_loss = 0.5970605 , gen_loss = 1.9651165
# Epoch = 0, Step = 1000, disc_loss = 0.6685476 , gen_loss = 2.7222018
# Epoch = 0, Step = 1100, disc_loss = 0.6080754 , gen_loss = 1.9946585
# Epoch = 0, Step = 1200, disc_loss = 1.0858917 , gen_loss = 0.9308838
# Epoch = 0, Step = 1300, disc_loss = 0.60251987 , gen_loss = 2.8574705
# Epoch = 0, Step = 1400, disc_loss = 0.73272055 , gen_loss = 1.4200853
# Epoch = 0, Step = 1500, disc_loss = 0.80353796 , gen_loss = 3.5452
# Epoch = 0, Step = 1600, disc_loss = 0.65126795 , gen_loss = 1.7173855
# Epoch = 0, Step = 1700, disc_loss = 0.98254573 , gen_loss = 1.0559808
# Epoch = 0, Step = 1800, disc_loss = 0.64658713 , gen_loss = 1.769405
# Epoch = 0, Step = 1900, disc_loss = 0.6257361 , gen_loss = 2.2766104
# Epoch = 0, Step = 2000, disc_loss = 0.6892689 , gen_loss = 1.5036726
# Epoch = 0, Step = 2100, disc_loss = 0.54680854 , gen_loss = 2.4270914
# Epoch = 0, Step = 2200, disc_loss = 0.7488514 , gen_loss = 1.3929052
# Epoch = 0, Step = 2300, disc_loss = 0.71007454 , gen_loss = 3.236602
# Epoch = 0, Step = 2400, disc_loss = 0.87310845 , gen_loss = 1.213564
# Epoch = 0, Step = 2500, disc_loss = 1.1242335 , gen_loss = 0.9027033
# Epoch = 0, Step = 2600, disc_loss = 0.7668739 , gen_loss = 2.7791886
# Epoch = 0, Step = 2700, disc_loss = 0.6657824 , gen_loss = 1.8128585
# Epoch = 0, Step = 2800, disc_loss = 0.7199153 , gen_loss = 1.6371956
# Epoch = 0, Step = 2900, disc_loss = 0.80816805 , gen_loss = 3.437656
# Epoch = 0, Step = 3000, disc_loss = 1.0368396 , gen_loss = 4.2937317
# Epoch = 0, Step = 3100, disc_loss = 1.0691524 , gen_loss = 0.8515745
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_0/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 0  ###
#
#
# Epoch = 1, Step = 0, disc_loss = 0.709347 , gen_loss = 1.7109668
# Epoch = 1, Step = 100, disc_loss = 1.8200723 , gen_loss = 5.6152625
# Epoch = 1, Step = 200, disc_loss = 0.8100194 , gen_loss = 1.3161463
# Epoch = 1, Step = 300, disc_loss = 0.8314854 , gen_loss = 1.210639
# Epoch = 1, Step = 400, disc_loss = 0.6254089 , gen_loss = 1.7317499
# Epoch = 1, Step = 500, disc_loss = 0.8428655 , gen_loss = 1.169302
# Epoch = 1, Step = 600, disc_loss = 0.7036951 , gen_loss = 2.5635526
# Epoch = 1, Step = 700, disc_loss = 0.63694763 , gen_loss = 1.9764919
# Epoch = 1, Step = 800, disc_loss = 1.4126531 , gen_loss = 3.9180536
# Epoch = 1, Step = 900, disc_loss = 0.72099715 , gen_loss = 2.0748587
# Epoch = 1, Step = 1000, disc_loss = 0.7838404 , gen_loss = 1.3032632
# Epoch = 1, Step = 1100, disc_loss = 1.0116721 , gen_loss = 1.008801
# Epoch = 1, Step = 1200, disc_loss = 1.9071859 , gen_loss = 0.4692387
# Epoch = 1, Step = 1300, disc_loss = 0.75741255 , gen_loss = 1.4644184
# Epoch = 1, Step = 1400, disc_loss = 0.8590384 , gen_loss = 1.1057539
# Epoch = 1, Step = 1500, disc_loss = 0.8944215 , gen_loss = 1.2856724
# Epoch = 1, Step = 1600, disc_loss = 0.7892531 , gen_loss = 2.6649323
# Epoch = 1, Step = 1700, disc_loss = 0.806747 , gen_loss = 1.422598
# Epoch = 1, Step = 1800, disc_loss = 0.8678637 , gen_loss = 1.3069259
# Epoch = 1, Step = 1900, disc_loss = 0.80954146 , gen_loss = 1.2881582
# Epoch = 1, Step = 2000, disc_loss = 0.6735044 , gen_loss = 1.7023313
# Epoch = 1, Step = 2100, disc_loss = 1.3825703 , gen_loss = 0.6516648
# Epoch = 1, Step = 2200, disc_loss = 0.79467916 , gen_loss = 1.3214787
# Epoch = 1, Step = 2300, disc_loss = 1.346186 , gen_loss = 0.7248367
# Epoch = 1, Step = 2400, disc_loss = 0.757812 , gen_loss = 1.4846985
# Epoch = 1, Step = 2500, disc_loss = 0.9640477 , gen_loss = 1.0634927
# Epoch = 1, Step = 2600, disc_loss = 0.69101965 , gen_loss = 2.293162
# Epoch = 1, Step = 2700, disc_loss = 0.74866056 , gen_loss = 1.6299685
# Epoch = 1, Step = 2800, disc_loss = 1.3270977 , gen_loss = 0.65112525
# Epoch = 1, Step = 2900, disc_loss = 0.8580401 , gen_loss = 1.216575
# Epoch = 1, Step = 3000, disc_loss = 0.7897977 , gen_loss = 2.4163842
# Epoch = 1, Step = 3100, disc_loss = 2.591445 , gen_loss = 0.4635391
# Epoch = 2, Step = 0, disc_loss = 0.88431454 , gen_loss = 1.0070376
# Epoch = 2, Step = 100, disc_loss = 0.7342822 , gen_loss = 1.7214732
# Epoch = 2, Step = 200, disc_loss = 5.2774005 , gen_loss = 0.48625416
# Epoch = 2, Step = 300, disc_loss = 1.1213136 , gen_loss = 0.7934436
# Epoch = 2, Step = 400, disc_loss = 0.7481929 , gen_loss = 2.8620734
# Epoch = 2, Step = 500, disc_loss = 1.9260471 , gen_loss = 0.48718318
# Epoch = 2, Step = 600, disc_loss = 0.8085007 , gen_loss = 1.3152224
# Epoch = 2, Step = 700, disc_loss = 0.7070478 , gen_loss = 1.6180296
# Epoch = 2, Step = 800, disc_loss = 0.94171643 , gen_loss = 1.3739841
# Epoch = 2, Step = 900, disc_loss = 0.8718256 , gen_loss = 1.2211955
# Epoch = 2, Step = 1000, disc_loss = 1.0182524 , gen_loss = 0.9244564
# Epoch = 2, Step = 1100, disc_loss = 0.69594705 , gen_loss = 1.7125009
# Epoch = 2, Step = 1200, disc_loss = 0.65959275 , gen_loss = 1.8844588
# Epoch = 2, Step = 1300, disc_loss = 1.4526014 , gen_loss = 0.59177196
# Epoch = 2, Step = 1400, disc_loss = 0.72127587 , gen_loss = 2.9092264
# Epoch = 2, Step = 1500, disc_loss = 0.87872744 , gen_loss = 1.187778
# Epoch = 2, Step = 1600, disc_loss = 0.99739945 , gen_loss = 0.91558105
# Epoch = 2, Step = 1700, disc_loss = 1.2884504 , gen_loss = 3.0790942
# Epoch = 2, Step = 1800, disc_loss = 1.1012396 , gen_loss = 0.8555453
# Epoch = 2, Step = 1900, disc_loss = 0.857945 , gen_loss = 2.4723794
# Epoch = 2, Step = 2000, disc_loss = 0.75448763 , gen_loss = 1.7386479
# Epoch = 2, Step = 2100, disc_loss = 1.136836 , gen_loss = 0.7423625
# Epoch = 2, Step = 2200, disc_loss = 1.2912648 , gen_loss = 0.809461
# Epoch = 2, Step = 2300, disc_loss = 0.78901225 , gen_loss = 1.2475969
# Epoch = 2, Step = 2400, disc_loss = 0.68720305 , gen_loss = 1.9296799
# Epoch = 2, Step = 2500, disc_loss = 0.972223 , gen_loss = 0.96055007
# Epoch = 2, Step = 2600, disc_loss = 1.0308667 , gen_loss = 1.0178285
# Epoch = 2, Step = 2700, disc_loss = 0.7478522 , gen_loss = 1.4820739
# Epoch = 2, Step = 2800, disc_loss = 2.148389 , gen_loss = 0.43242148
# Epoch = 2, Step = 2900, disc_loss = 0.73788524 , gen_loss = 1.7822254
# Epoch = 2, Step = 3000, disc_loss = 1.4903505 , gen_loss = 3.8212142
# Epoch = 2, Step = 3100, disc_loss = 0.7561118 , gen_loss = 1.4958664
# Epoch = 3, Step = 0, disc_loss = 0.82686436 , gen_loss = 1.1157618
# Epoch = 3, Step = 100, disc_loss = 0.92486304 , gen_loss = 1.0320382
# Epoch = 3, Step = 200, disc_loss = 0.79846525 , gen_loss = 1.4672737
# Epoch = 3, Step = 300, disc_loss = 0.99420094 , gen_loss = 0.9451378
# Epoch = 3, Step = 400, disc_loss = 0.89924526 , gen_loss = 2.93831
# Epoch = 3, Step = 500, disc_loss = 0.6518104 , gen_loss = 1.543189
# Epoch = 3, Step = 600, disc_loss = 1.0102117 , gen_loss = 1.4995542
# Epoch = 3, Step = 700, disc_loss = 0.8083573 , gen_loss = 3.388807
# Epoch = 3, Step = 800, disc_loss = 1.1771864 , gen_loss = 0.76990634
# Epoch = 3, Step = 900, disc_loss = 0.819011 , gen_loss = 1.2212316
# Epoch = 3, Step = 1000, disc_loss = 0.7017616 , gen_loss = 1.5405346
# Epoch = 3, Step = 1100, disc_loss = 0.53393626 , gen_loss = 2.245974
# Epoch = 3, Step = 1200, disc_loss = 0.90815306 , gen_loss = 2.7788038
# Epoch = 3, Step = 1300, disc_loss = 1.1795245 , gen_loss = 0.7269382
# Epoch = 3, Step = 1400, disc_loss = 0.9986237 , gen_loss = 0.9183027
# Epoch = 3, Step = 1500, disc_loss = 0.75784075 , gen_loss = 1.3616867
# Epoch = 3, Step = 1600, disc_loss = 2.1658833 , gen_loss = 0.41412023
# Epoch = 3, Step = 1700, disc_loss = 0.82730687 , gen_loss = 2.5891209
# Epoch = 3, Step = 1800, disc_loss = 1.2962146 , gen_loss = 0.66672313
# Epoch = 3, Step = 1900, disc_loss = 0.7711899 , gen_loss = 1.5107813
# Epoch = 3, Step = 2000, disc_loss = 1.0011935 , gen_loss = 0.93764794
# Epoch = 3, Step = 2100, disc_loss = 2.9895995 , gen_loss = 5.7177267
# Epoch = 3, Step = 2200, disc_loss = 1.1595657 , gen_loss = 0.7491864
# Epoch = 3, Step = 2300, disc_loss = 0.88394034 , gen_loss = 1.1050534
# Epoch = 3, Step = 2400, disc_loss = 0.5977398 , gen_loss = 2.5293994
# Epoch = 3, Step = 2500, disc_loss = 1.5827464 , gen_loss = 0.5836794
# Epoch = 3, Step = 2600, disc_loss = 0.6839945 , gen_loss = 1.5474572
# Epoch = 3, Step = 2700, disc_loss = 0.62782776 , gen_loss = 1.8915646
# Epoch = 3, Step = 2800, disc_loss = 1.2290187 , gen_loss = 0.68365484
# Epoch = 3, Step = 2900, disc_loss = 0.89524376 , gen_loss = 1.0616891
# Epoch = 3, Step = 3000, disc_loss = 0.9012602 , gen_loss = 1.0526066
# Epoch = 3, Step = 3100, disc_loss = 0.7768568 , gen_loss = 1.231344
# Epoch = 4, Step = 0, disc_loss = 0.7214016 , gen_loss = 1.5478742
# Epoch = 4, Step = 100, disc_loss = 0.9031395 , gen_loss = 1.0661722
# Epoch = 4, Step = 200, disc_loss = 0.6346915 , gen_loss = 1.9195251
# Epoch = 4, Step = 300, disc_loss = 0.6275329 , gen_loss = 1.9217705
# Epoch = 4, Step = 400, disc_loss = 0.6445013 , gen_loss = 1.8773233
# Epoch = 4, Step = 500, disc_loss = 1.4890478 , gen_loss = 0.6700216
# Epoch = 4, Step = 600, disc_loss = 0.6675302 , gen_loss = 1.7992074
# Epoch = 4, Step = 700, disc_loss = 0.6845546 , gen_loss = 1.5619427
# Epoch = 4, Step = 800, disc_loss = 2.1551142 , gen_loss = 0.49024332
# Epoch = 4, Step = 900, disc_loss = 0.64235175 , gen_loss = 2.4192052
# Epoch = 4, Step = 1000, disc_loss = 0.65113485 , gen_loss = 1.705303
# Epoch = 4, Step = 1100, disc_loss = 0.58268327 , gen_loss = 2.1158133
# Epoch = 4, Step = 1200, disc_loss = 0.61252654 , gen_loss = 1.6185203
# Epoch = 4, Step = 1300, disc_loss = 1.2577989 , gen_loss = 0.8053824
# Epoch = 4, Step = 1400, disc_loss = 0.6623954 , gen_loss = 1.5166816
# Epoch = 4, Step = 1500, disc_loss = 0.621664 , gen_loss = 1.813816
# Epoch = 4, Step = 1600, disc_loss = 1.8800826 , gen_loss = 0.53148156
# Epoch = 4, Step = 1700, disc_loss = 0.687246 , gen_loss = 1.5156248
# Epoch = 4, Step = 1800, disc_loss = 1.8646553 , gen_loss = 0.55383706
# Epoch = 4, Step = 1900, disc_loss = 0.58677673 , gen_loss = 1.8456444
# Epoch = 4, Step = 2000, disc_loss = 0.99948215 , gen_loss = 1.0318505
# Epoch = 4, Step = 2100, disc_loss = 1.0452924 , gen_loss = 0.85638565
# Epoch = 4, Step = 2200, disc_loss = 1.1329604 , gen_loss = 0.9982711
# Epoch = 4, Step = 2300, disc_loss = 0.75267553 , gen_loss = 1.3333333
# Epoch = 4, Step = 2400, disc_loss = 0.9824171 , gen_loss = 0.933263
# Epoch = 4, Step = 2500, disc_loss = 0.94440156 , gen_loss = 1.1082
# Epoch = 4, Step = 2600, disc_loss = 1.1897632 , gen_loss = 0.7805063
# Epoch = 4, Step = 2700, disc_loss = 0.82861996 , gen_loss = 1.1977667
# Epoch = 4, Step = 2800, disc_loss = 0.57834226 , gen_loss = 2.115357
# Epoch = 4, Step = 2900, disc_loss = 0.7916411 , gen_loss = 1.2663072
# Epoch = 4, Step = 3000, disc_loss = 0.6738953 , gen_loss = 1.5676571
# Epoch = 4, Step = 3100, disc_loss = 1.0841796 , gen_loss = 0.8509756
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_4/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 4  ###
#
#
# Epoch = 5, Step = 0, disc_loss = 0.6044295 , gen_loss = 1.7783531
# Epoch = 5, Step = 100, disc_loss = 0.61361474 , gen_loss = 1.6750721
# Epoch = 5, Step = 200, disc_loss = 0.799718 , gen_loss = 1.3987887
# Epoch = 5, Step = 300, disc_loss = 0.49311328 , gen_loss = 2.6410418
# Epoch = 5, Step = 400, disc_loss = 0.5755842 , gen_loss = 1.8528116
# Epoch = 5, Step = 500, disc_loss = 0.84154785 , gen_loss = 1.2419966
# Epoch = 5, Step = 600, disc_loss = 0.49083576 , gen_loss = 2.4138973
# Epoch = 5, Step = 700, disc_loss = 1.033092 , gen_loss = 1.0351654
# Epoch = 5, Step = 800, disc_loss = 2.191307 , gen_loss = 0.4296835
# Epoch = 5, Step = 900, disc_loss = 0.47716674 , gen_loss = 2.884934
# Epoch = 5, Step = 1000, disc_loss = 0.53885186 , gen_loss = 2.1300955
# Epoch = 5, Step = 1100, disc_loss = 0.4826448 , gen_loss = 2.3076358
# Epoch = 5, Step = 1200, disc_loss = 0.5848255 , gen_loss = 1.7023816
# Epoch = 5, Step = 1300, disc_loss = 0.7575259 , gen_loss = 1.270107
# Epoch = 5, Step = 1400, disc_loss = 0.67417324 , gen_loss = 1.4696846
# Epoch = 5, Step = 1500, disc_loss = 0.43826094 , gen_loss = 3.1364155
# Epoch = 5, Step = 1600, disc_loss = 0.6787467 , gen_loss = 1.4429592
# Epoch = 5, Step = 1700, disc_loss = 0.6725806 , gen_loss = 1.484678
# Epoch = 5, Step = 1800, disc_loss = 0.67705786 , gen_loss = 1.4999479
# Epoch = 5, Step = 1900, disc_loss = 0.58733726 , gen_loss = 1.9248629
# Epoch = 5, Step = 2000, disc_loss = 0.6601169 , gen_loss = 1.4541965
# Epoch = 5, Step = 2100, disc_loss = 0.6199779 , gen_loss = 1.6756774
# Epoch = 5, Step = 2200, disc_loss = 1.2573193 , gen_loss = 0.90735835
# Epoch = 5, Step = 2300, disc_loss = 0.5782888 , gen_loss = 1.8120883
# Epoch = 5, Step = 2400, disc_loss = 0.75690794 , gen_loss = 1.2490876
# Epoch = 5, Step = 2500, disc_loss = 0.5450097 , gen_loss = 1.930655
# Epoch = 5, Step = 2600, disc_loss = 1.0297611 , gen_loss = 0.91670495
# Epoch = 5, Step = 2700, disc_loss = 0.49617502 , gen_loss = 2.2545877
# Epoch = 5, Step = 2800, disc_loss = 1.3489953 , gen_loss = 2.7675734
# Epoch = 5, Step = 2900, disc_loss = 0.5821681 , gen_loss = 2.9632258
# Epoch = 5, Step = 3000, disc_loss = 0.48310345 , gen_loss = 2.8425832
# Epoch = 5, Step = 3100, disc_loss = 0.7997211 , gen_loss = 1.1334759
# Epoch = 6, Step = 0, disc_loss = 0.5723047 , gen_loss = 1.7580273
# Epoch = 6, Step = 100, disc_loss = 0.75585157 , gen_loss = 1.3030902
# Epoch = 6, Step = 200, disc_loss = 0.59880733 , gen_loss = 1.6651505
# Epoch = 6, Step = 300, disc_loss = 0.64538825 , gen_loss = 4.4105763
# Epoch = 6, Step = 400, disc_loss = 0.57215226 , gen_loss = 2.1219099
# Epoch = 6, Step = 500, disc_loss = 0.531728 , gen_loss = 2.4816105
# Epoch = 6, Step = 600, disc_loss = 0.47327724 , gen_loss = 2.6449265
# Epoch = 6, Step = 700, disc_loss = 0.52708113 , gen_loss = 2.5794244
# Epoch = 6, Step = 800, disc_loss = 0.9996286 , gen_loss = 1.1754487
# Epoch = 6, Step = 900, disc_loss = 0.50542986 , gen_loss = 2.2140732
# Epoch = 6, Step = 1000, disc_loss = 0.6047788 , gen_loss = 1.6447535
# Epoch = 6, Step = 1100, disc_loss = 0.5652771 , gen_loss = 3.5347514
# Epoch = 6, Step = 1200, disc_loss = 0.6716887 , gen_loss = 1.481524
# Epoch = 6, Step = 1300, disc_loss = 0.58798134 , gen_loss = 1.6971488
# Epoch = 6, Step = 1400, disc_loss = 0.49190533 , gen_loss = 2.1696386
# Epoch = 6, Step = 1500, disc_loss = 0.5068825 , gen_loss = 2.3145235
# Epoch = 6, Step = 1600, disc_loss = 0.53645855 , gen_loss = 1.9988227
# Epoch = 6, Step = 1700, disc_loss = 0.6088679 , gen_loss = 1.6531699
# Epoch = 6, Step = 1800, disc_loss = 0.66876984 , gen_loss = 1.5152284
# Epoch = 6, Step = 1900, disc_loss = 0.62166333 , gen_loss = 1.9507506
# Epoch = 6, Step = 2000, disc_loss = 0.7195064 , gen_loss = 2.5247567
# Epoch = 6, Step = 2100, disc_loss = 0.87635577 , gen_loss = 3.2104263
# Epoch = 6, Step = 2200, disc_loss = 1.0030515 , gen_loss = 1.0926784
# Epoch = 6, Step = 2300, disc_loss = 0.8071825 , gen_loss = 1.3329465
# Epoch = 6, Step = 2400, disc_loss = 0.53342986 , gen_loss = 1.9856449
# Epoch = 6, Step = 2500, disc_loss = 0.4281632 , gen_loss = 3.0121217
# Epoch = 6, Step = 2600, disc_loss = 0.784818 , gen_loss = 1.2627188
# Epoch = 6, Step = 2700, disc_loss = 0.6971011 , gen_loss = 1.475194
# Epoch = 6, Step = 2800, disc_loss = 0.5044836 , gen_loss = 2.395205
# Epoch = 6, Step = 2900, disc_loss = 0.64389485 , gen_loss = 1.5470631
# Epoch = 6, Step = 3000, disc_loss = 0.81018686 , gen_loss = 1.1426649
# Epoch = 6, Step = 3100, disc_loss = 0.57759714 , gen_loss = 1.7822093
# Epoch = 7, Step = 0, disc_loss = 0.6451802 , gen_loss = 1.5228984
# Epoch = 7, Step = 100, disc_loss = 0.59822994 , gen_loss = 2.0002322
# Epoch = 7, Step = 200, disc_loss = 0.5266489 , gen_loss = 1.9195712
# Epoch = 7, Step = 300, disc_loss = 0.6201307 , gen_loss = 1.7038392
# Epoch = 7, Step = 400, disc_loss = 0.77351886 , gen_loss = 4.3785005
# Epoch = 7, Step = 500, disc_loss = 0.4446174 , gen_loss = 2.7863367
# Epoch = 7, Step = 600, disc_loss = 0.4031742 , gen_loss = 3.2455928
# Epoch = 7, Step = 700, disc_loss = 0.6107085 , gen_loss = 1.64077
# Epoch = 7, Step = 800, disc_loss = 0.48538256 , gen_loss = 2.2041404
# Epoch = 7, Step = 900, disc_loss = 0.512401 , gen_loss = 2.1381207
# Epoch = 7, Step = 1000, disc_loss = 0.4537449 , gen_loss = 2.4907403
# Epoch = 7, Step = 1100, disc_loss = 1.1408111 , gen_loss = 1.0408294
# Epoch = 7, Step = 1200, disc_loss = 0.6517781 , gen_loss = 1.5608513
# Epoch = 7, Step = 1300, disc_loss = 0.7122098 , gen_loss = 1.5365305
# Epoch = 7, Step = 1400, disc_loss = 0.47946697 , gen_loss = 2.3365078
# Epoch = 7, Step = 1500, disc_loss = 0.47260454 , gen_loss = 2.3325768
# Epoch = 7, Step = 1600, disc_loss = 0.6719682 , gen_loss = 1.5462861
# Epoch = 7, Step = 1700, disc_loss = 0.55627245 , gen_loss = 1.8489399
# Epoch = 7, Step = 1800, disc_loss = 0.5328415 , gen_loss = 1.9371132
# Epoch = 7, Step = 1900, disc_loss = 0.58503157 , gen_loss = 1.7225809
# Epoch = 7, Step = 2000, disc_loss = 0.49903142 , gen_loss = 2.4696276
# Epoch = 7, Step = 2100, disc_loss = 0.90906966 , gen_loss = 1.2062383
# Epoch = 7, Step = 2200, disc_loss = 0.4998122 , gen_loss = 2.2034988
# Epoch = 7, Step = 2300, disc_loss = 0.90982854 , gen_loss = 1.0706551
# Epoch = 7, Step = 2400, disc_loss = 0.79916954 , gen_loss = 1.2106142
# Epoch = 7, Step = 2500, disc_loss = 0.5160487 , gen_loss = 2.1190338
# Epoch = 7, Step = 2600, disc_loss = 0.8336666 , gen_loss = 1.3080881
# Epoch = 7, Step = 2700, disc_loss = 0.580006 , gen_loss = 2.0549362
# Epoch = 7, Step = 2800, disc_loss = 0.6044037 , gen_loss = 2.4745567
# Epoch = 7, Step = 2900, disc_loss = 0.7089598 , gen_loss = 1.4374397
# Epoch = 7, Step = 3000, disc_loss = 0.42764297 , gen_loss = 2.8963814
# Epoch = 7, Step = 3100, disc_loss = 0.6120815 , gen_loss = 1.6237854
# Epoch = 8, Step = 0, disc_loss = 0.46672004 , gen_loss = 2.78727
# Epoch = 8, Step = 100, disc_loss = 0.45452318 , gen_loss = 2.7294352
# Epoch = 8, Step = 200, disc_loss = 0.5659664 , gen_loss = 1.8012236
# Epoch = 8, Step = 300, disc_loss = 0.54878795 , gen_loss = 1.8547544
# Epoch = 8, Step = 400, disc_loss = 0.50551456 , gen_loss = 3.208665
# Epoch = 8, Step = 500, disc_loss = 0.46428788 , gen_loss = 2.4630108
# Epoch = 8, Step = 600, disc_loss = 0.44268864 , gen_loss = 2.728179
# Epoch = 8, Step = 700, disc_loss = 0.6061115 , gen_loss = 1.7124124
# Epoch = 8, Step = 800, disc_loss = 0.47718233 , gen_loss = 2.8215823
# Epoch = 8, Step = 900, disc_loss = 0.4805727 , gen_loss = 3.3547583
# Epoch = 8, Step = 1000, disc_loss = 0.46748942 , gen_loss = 2.7295904
# Epoch = 8, Step = 1100, disc_loss = 0.4508267 , gen_loss = 2.9200635
# Epoch = 8, Step = 1200, disc_loss = 0.6906843 , gen_loss = 1.4623207
# Epoch = 8, Step = 1300, disc_loss = 0.41212592 , gen_loss = 3.0187278
# Epoch = 8, Step = 1400, disc_loss = 0.52096903 , gen_loss = 2.0796523
# Epoch = 8, Step = 1500, disc_loss = 0.5135364 , gen_loss = 2.015318
# Epoch = 8, Step = 1600, disc_loss = 0.6823693 , gen_loss = 1.5095859
# Epoch = 8, Step = 1700, disc_loss = 0.6322973 , gen_loss = 1.5801892
# Epoch = 8, Step = 1800, disc_loss = 0.53064066 , gen_loss = 1.95978
# Epoch = 8, Step = 1900, disc_loss = 0.5071203 , gen_loss = 1.9920619
# Epoch = 8, Step = 2000, disc_loss = 0.47608972 , gen_loss = 2.418858
# Epoch = 8, Step = 2100, disc_loss = 1.978584 , gen_loss = 0.5330937
# Epoch = 8, Step = 2200, disc_loss = 0.53573334 , gen_loss = 1.91504
# Epoch = 8, Step = 2300, disc_loss = 0.54822356 , gen_loss = 1.9556782
# Epoch = 8, Step = 2400, disc_loss = 0.59696674 , gen_loss = 1.7796974
# Epoch = 8, Step = 2500, disc_loss = 0.45226702 , gen_loss = 2.461594
# Epoch = 8, Step = 2600, disc_loss = 0.7622358 , gen_loss = 1.3187926
# Epoch = 8, Step = 2700, disc_loss = 0.49882072 , gen_loss = 2.1697013
# Epoch = 8, Step = 2800, disc_loss = 0.4697731 , gen_loss = 2.338184
# Epoch = 8, Step = 2900, disc_loss = 0.6798759 , gen_loss = 4.116729
# Epoch = 8, Step = 3000, disc_loss = 0.48773718 , gen_loss = 2.1900785
# Epoch = 8, Step = 3100, disc_loss = 1.7295767 , gen_loss = 5.5350876
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_8/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 8  ###
#
#
# Epoch = 9, Step = 0, disc_loss = 0.47098416 , gen_loss = 2.7407267
# Epoch = 9, Step = 100, disc_loss = 0.47283965 , gen_loss = 2.3249948
# Epoch = 9, Step = 200, disc_loss = 0.62648624 , gen_loss = 1.7622689
# Epoch = 9, Step = 300, disc_loss = 0.42752087 , gen_loss = 2.7694016
# Epoch = 9, Step = 400, disc_loss = 0.42964643 , gen_loss = 2.7576807
# Epoch = 9, Step = 500, disc_loss = 0.40948793 , gen_loss = 3.353942
# Epoch = 9, Step = 600, disc_loss = 0.4126391 , gen_loss = 2.9745183
# Epoch = 9, Step = 700, disc_loss = 0.4131508 , gen_loss = 2.8861067
# Epoch = 9, Step = 800, disc_loss = 0.74631745 , gen_loss = 1.3533896
# Epoch = 9, Step = 900, disc_loss = 0.41057575 , gen_loss = 3.0149589
# Epoch = 9, Step = 1000, disc_loss = 0.43848568 , gen_loss = 2.7436397
# Epoch = 9, Step = 1100, disc_loss = 0.49155822 , gen_loss = 3.009213
# Epoch = 9, Step = 1200, disc_loss = 0.48234975 , gen_loss = 2.3754117
# Epoch = 9, Step = 1300, disc_loss = 0.5315537 , gen_loss = 1.9943651
# Epoch = 9, Step = 1400, disc_loss = 0.48951685 , gen_loss = 2.960501
# Epoch = 9, Step = 1500, disc_loss = 0.6189962 , gen_loss = 1.5564978
# Epoch = 9, Step = 1600, disc_loss = 1.0663786 , gen_loss = 0.93700904
# Epoch = 9, Step = 1700, disc_loss = 0.55367815 , gen_loss = 1.9099641
# Epoch = 9, Step = 1800, disc_loss = 0.6900531 , gen_loss = 1.5223142
# Epoch = 9, Step = 1900, disc_loss = 0.5894798 , gen_loss = 1.8603115
# Epoch = 9, Step = 2000, disc_loss = 0.5753889 , gen_loss = 1.7103409
# Epoch = 9, Step = 2100, disc_loss = 0.9193437 , gen_loss = 1.0758765
# Epoch = 9, Step = 2200, disc_loss = 0.65161717 , gen_loss = 1.5177451
# Epoch = 9, Step = 2300, disc_loss = 0.8294548 , gen_loss = 1.2930925
# Epoch = 9, Step = 2400, disc_loss = 0.70469177 , gen_loss = 1.4046196
# Epoch = 9, Step = 2500, disc_loss = 0.43564096 , gen_loss = 2.5636344
# Epoch = 9, Step = 2600, disc_loss = 1.6122228 , gen_loss = 0.67216593
# Epoch = 9, Step = 2700, disc_loss = 0.40448326 , gen_loss = 3.0356338
# Epoch = 9, Step = 2800, disc_loss = 0.46968105 , gen_loss = 2.8509276
# Epoch = 9, Step = 2900, disc_loss = 0.61572623 , gen_loss = 3.7539568
# Epoch = 9, Step = 3000, disc_loss = 0.45458493 , gen_loss = 2.4548006
# Epoch = 9, Step = 3100, disc_loss = 1.0555632 , gen_loss = 1.0600017
# Epoch = 10, Step = 0, disc_loss = 0.84385884 , gen_loss = 1.1046661
# Epoch = 10, Step = 100, disc_loss = 0.4942122 , gen_loss = 2.2267473
# Epoch = 10, Step = 200, disc_loss = 0.48703203 , gen_loss = 2.359106
# Epoch = 10, Step = 300, disc_loss = 0.44162014 , gen_loss = 2.677124
# Epoch = 10, Step = 400, disc_loss = 0.48896617 , gen_loss = 2.118638
# Epoch = 10, Step = 500, disc_loss = 0.47121647 , gen_loss = 3.0404716
# Epoch = 10, Step = 600, disc_loss = 0.413845 , gen_loss = 3.1644392
# Epoch = 10, Step = 700, disc_loss = 0.70294976 , gen_loss = 1.6480545
# Epoch = 10, Step = 800, disc_loss = 0.4715523 , gen_loss = 2.3070443
# Epoch = 10, Step = 900, disc_loss = 0.502066 , gen_loss = 2.388542
# Epoch = 10, Step = 1000, disc_loss = 0.4686592 , gen_loss = 2.467487
# Epoch = 10, Step = 1100, disc_loss = 0.933858 , gen_loss = 1.0546
# Epoch = 10, Step = 1200, disc_loss = 0.78792167 , gen_loss = 1.3888433
# Epoch = 10, Step = 1300, disc_loss = 0.4268818 , gen_loss = 2.8020191
# Epoch = 10, Step = 1400, disc_loss = 0.54771096 , gen_loss = 1.8640378
# Epoch = 10, Step = 1500, disc_loss = 1.1908134 , gen_loss = 4.6003823
# Epoch = 10, Step = 1600, disc_loss = 0.5588913 , gen_loss = 1.8385172
# Epoch = 10, Step = 1700, disc_loss = 0.6408274 , gen_loss = 1.8855458
# Epoch = 10, Step = 1800, disc_loss = 0.51470965 , gen_loss = 2.0684767
# Epoch = 10, Step = 1900, disc_loss = 0.69044495 , gen_loss = 1.5518996
# Epoch = 10, Step = 2000, disc_loss = 0.4429139 , gen_loss = 2.5901291
# Epoch = 10, Step = 2100, disc_loss = 0.9655434 , gen_loss = 1.0540559
# Epoch = 10, Step = 2200, disc_loss = 0.4804632 , gen_loss = 2.220264
# Epoch = 10, Step = 2300, disc_loss = 0.50574577 , gen_loss = 2.1042025
# Epoch = 10, Step = 2400, disc_loss = 0.7668315 , gen_loss = 1.333392
# Epoch = 10, Step = 2500, disc_loss = 0.57972014 , gen_loss = 1.9292535
# Epoch = 10, Step = 2600, disc_loss = 0.97501695 , gen_loss = 1.1486728
# Epoch = 10, Step = 2700, disc_loss = 0.44656438 , gen_loss = 2.5233395
# Epoch = 10, Step = 2800, disc_loss = 0.47969347 , gen_loss = 2.3645325
# Epoch = 10, Step = 2900, disc_loss = 0.6306488 , gen_loss = 1.9440136
# Epoch = 10, Step = 3000, disc_loss = 0.43225423 , gen_loss = 2.985436
# Epoch = 10, Step = 3100, disc_loss = 0.63723814 , gen_loss = 1.7376825
# Epoch = 11, Step = 0, disc_loss = 0.4829788 , gen_loss = 2.2573638
# Epoch = 11, Step = 100, disc_loss = 0.6243062 , gen_loss = 1.5843791
# Epoch = 11, Step = 200, disc_loss = 0.46889898 , gen_loss = 2.2832317
# Epoch = 11, Step = 300, disc_loss = 0.42485476 , gen_loss = 2.872096
# Epoch = 11, Step = 400, disc_loss = 0.4718683 , gen_loss = 2.3113718
# Epoch = 11, Step = 500, disc_loss = 0.4145869 , gen_loss = 3.2143118
# Epoch = 11, Step = 600, disc_loss = 0.51012033 , gen_loss = 2.021325
# Epoch = 11, Step = 700, disc_loss = 0.4327014 , gen_loss = 2.7547607
# Epoch = 11, Step = 800, disc_loss = 0.43657142 , gen_loss = 2.5824084
# Epoch = 11, Step = 900, disc_loss = 0.6008942 , gen_loss = 1.7558302
# Epoch = 11, Step = 1000, disc_loss = 0.510049 , gen_loss = 2.2469618
# Epoch = 11, Step = 1100, disc_loss = 0.43724 , gen_loss = 2.8137841
# Epoch = 11, Step = 1200, disc_loss = 0.441697 , gen_loss = 2.5488808
# Epoch = 11, Step = 1300, disc_loss = 0.5393445 , gen_loss = 1.9875486
# Epoch = 11, Step = 1400, disc_loss = 0.77183855 , gen_loss = 1.3771738
# Epoch = 11, Step = 1500, disc_loss = 0.48234105 , gen_loss = 2.285196
# Epoch = 11, Step = 1600, disc_loss = 0.48558134 , gen_loss = 2.2138574
# Epoch = 11, Step = 1700, disc_loss = 0.6218487 , gen_loss = 1.6434851
# Epoch = 11, Step = 1800, disc_loss = 0.6516357 , gen_loss = 1.6345265
# Epoch = 11, Step = 1900, disc_loss = 0.41645548 , gen_loss = 3.2919085
# Epoch = 11, Step = 2000, disc_loss = 0.45162606 , gen_loss = 2.3907435
# Epoch = 11, Step = 2100, disc_loss = 0.5374888 , gen_loss = 2.0424607
# Epoch = 11, Step = 2200, disc_loss = 0.51627445 , gen_loss = 1.9619441
# Epoch = 11, Step = 2300, disc_loss = 0.5629672 , gen_loss = 1.9008799
# Epoch = 11, Step = 2400, disc_loss = 1.357701 , gen_loss = 0.7867418
# Epoch = 11, Step = 2500, disc_loss = 0.50543916 , gen_loss = 2.165111
# Epoch = 11, Step = 2600, disc_loss = 0.7757298 , gen_loss = 1.3430594
# Epoch = 11, Step = 2700, disc_loss = 0.41539693 , gen_loss = 2.854073
# Epoch = 11, Step = 2800, disc_loss = 0.6159308 , gen_loss = 1.5753721
# Epoch = 11, Step = 2900, disc_loss = 1.535528 , gen_loss = 0.6659705
# Epoch = 11, Step = 3000, disc_loss = 0.46827677 , gen_loss = 2.4308002
# Epoch = 11, Step = 3100, disc_loss = 0.9681628 , gen_loss = 1.314404
# Epoch = 12, Step = 0, disc_loss = 0.44282895 , gen_loss = 2.5949621
# Epoch = 12, Step = 100, disc_loss = 1.5233555 , gen_loss = 0.69674736
# Epoch = 12, Step = 200, disc_loss = 0.4701926 , gen_loss = 3.2099795
# Epoch = 12, Step = 300, disc_loss = 0.38579115 , gen_loss = 3.213985
# Epoch = 12, Step = 400, disc_loss = 0.62806904 , gen_loss = 1.6059391
# Epoch = 12, Step = 500, disc_loss = 0.4092953 , gen_loss = 3.2439947
# Epoch = 12, Step = 600, disc_loss = 2.5398607 , gen_loss = 7.37022
# Epoch = 12, Step = 700, disc_loss = 0.52129406 , gen_loss = 1.982423
# Epoch = 12, Step = 800, disc_loss = 0.4302765 , gen_loss = 2.6619053
# Epoch = 12, Step = 900, disc_loss = 0.41713715 , gen_loss = 2.7639246
# Epoch = 12, Step = 1000, disc_loss = 0.4535486 , gen_loss = 2.41993
# Epoch = 12, Step = 1100, disc_loss = 0.61651653 , gen_loss = 2.6784596
# Epoch = 12, Step = 1200, disc_loss = 0.44232053 , gen_loss = 2.685549
# Epoch = 12, Step = 1300, disc_loss = 0.40297505 , gen_loss = 2.9364188
# Epoch = 12, Step = 1400, disc_loss = 0.42984763 , gen_loss = 2.810001
# Epoch = 12, Step = 1500, disc_loss = 0.42125654 , gen_loss = 2.9899395
# Epoch = 12, Step = 1600, disc_loss = 0.74988985 , gen_loss = 1.5110826
# Epoch = 12, Step = 1700, disc_loss = 0.46649474 , gen_loss = 2.273381
# Epoch = 12, Step = 1800, disc_loss = 0.523325 , gen_loss = 1.9323941
# Epoch = 12, Step = 1900, disc_loss = 0.42726064 , gen_loss = 2.8231597
# Epoch = 12, Step = 2000, disc_loss = 0.43711463 , gen_loss = 2.4696503
# Epoch = 12, Step = 2100, disc_loss = 0.74150133 , gen_loss = 1.6737435
# Epoch = 12, Step = 2200, disc_loss = 0.43027163 , gen_loss = 2.6336231
# Epoch = 12, Step = 2300, disc_loss = 0.5352022 , gen_loss = 1.9617608
# Epoch = 12, Step = 2400, disc_loss = 0.54996425 , gen_loss = 1.7834393
# Epoch = 12, Step = 2500, disc_loss = 0.46627313 , gen_loss = 4.128267
# Epoch = 12, Step = 2600, disc_loss = 0.58037996 , gen_loss = 1.8598951
# Epoch = 12, Step = 2700, disc_loss = 0.78996277 , gen_loss = 1.4653102
# Epoch = 12, Step = 2800, disc_loss = 0.45077395 , gen_loss = 2.9954853
# Epoch = 12, Step = 2900, disc_loss = 0.79340434 , gen_loss = 1.2759055
# Epoch = 12, Step = 3000, disc_loss = 0.4416812 , gen_loss = 2.6371036
# Epoch = 12, Step = 3100, disc_loss = 0.6665623 , gen_loss = 1.4883307
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_12/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 12  ###
#
#
# Epoch = 13, Step = 0, disc_loss = 0.49175107 , gen_loss = 2.2576628
# Epoch = 13, Step = 100, disc_loss = 0.41084105 , gen_loss = 2.843732
# Epoch = 13, Step = 200, disc_loss = 0.54582906 , gen_loss = 4.1340876
# Epoch = 13, Step = 300, disc_loss = 0.41198894 , gen_loss = 3.0515015
# Epoch = 13, Step = 400, disc_loss = 0.43501484 , gen_loss = 2.7123418
# Epoch = 13, Step = 500, disc_loss = 0.45947102 , gen_loss = 2.885263
# Epoch = 13, Step = 600, disc_loss = 0.44340655 , gen_loss = 2.6056871
# Epoch = 13, Step = 700, disc_loss = 0.4003343 , gen_loss = 3.2159758
# Epoch = 13, Step = 800, disc_loss = 0.76587665 , gen_loss = 1.3331306
# Epoch = 13, Step = 900, disc_loss = 0.46057338 , gen_loss = 2.3850517
# Epoch = 13, Step = 1000, disc_loss = 0.54693836 , gen_loss = 1.9797032
# Epoch = 13, Step = 1100, disc_loss = 0.45655376 , gen_loss = 2.420687
# Epoch = 13, Step = 1200, disc_loss = 0.42185026 , gen_loss = 2.768793
# Epoch = 13, Step = 1300, disc_loss = 0.43980038 , gen_loss = 2.7199445
# Epoch = 13, Step = 1400, disc_loss = 0.44313735 , gen_loss = 2.4826143
# Epoch = 13, Step = 1500, disc_loss = 0.41919628 , gen_loss = 2.9524567
# Epoch = 13, Step = 1600, disc_loss = 0.8540645 , gen_loss = 1.4639297
# Epoch = 13, Step = 1700, disc_loss = 0.4668366 , gen_loss = 2.3645782
# Epoch = 13, Step = 1800, disc_loss = 0.48704547 , gen_loss = 2.225175
# Epoch = 13, Step = 1900, disc_loss = 0.77948606 , gen_loss = 1.1951202
# Epoch = 13, Step = 2000, disc_loss = 0.5549394 , gen_loss = 1.8437521
# Epoch = 13, Step = 2100, disc_loss = 1.0392292 , gen_loss = 2.4268513
# Epoch = 13, Step = 2200, disc_loss = 0.57365084 , gen_loss = 2.3767908
# Epoch = 13, Step = 2300, disc_loss = 0.4910121 , gen_loss = 2.1456025
# Epoch = 13, Step = 2400, disc_loss = 0.47082368 , gen_loss = 2.248225
# Epoch = 13, Step = 2500, disc_loss = 0.6238969 , gen_loss = 2.0670114
# Epoch = 13, Step = 2600, disc_loss = 0.7752754 , gen_loss = 1.5256495
# Epoch = 13, Step = 2700, disc_loss = 0.51650655 , gen_loss = 2.0529404
# Epoch = 13, Step = 2800, disc_loss = 0.40854904 , gen_loss = 3.03859
# Epoch = 13, Step = 2900, disc_loss = 0.61108315 , gen_loss = 1.6958617
# Epoch = 13, Step = 3000, disc_loss = 0.4304104 , gen_loss = 2.6995358
# Epoch = 13, Step = 3100, disc_loss = 0.71298814 , gen_loss = 1.4188719
# Epoch = 14, Step = 0, disc_loss = 0.6100051 , gen_loss = 1.5948658
# Epoch = 14, Step = 100, disc_loss = 0.6725857 , gen_loss = 1.7005069
# Epoch = 14, Step = 200, disc_loss = 0.46944278 , gen_loss = 2.2078376
# Epoch = 14, Step = 300, disc_loss = 0.45052728 , gen_loss = 2.4249198
# Epoch = 14, Step = 400, disc_loss = 0.46041867 , gen_loss = 2.601341
# Epoch = 14, Step = 500, disc_loss = 0.44389182 , gen_loss = 2.5214067
# Epoch = 14, Step = 600, disc_loss = 0.4536264 , gen_loss = 2.7088108
# Epoch = 14, Step = 700, disc_loss = 0.39749777 , gen_loss = 3.1366825
# Epoch = 14, Step = 800, disc_loss = 0.52429855 , gen_loss = 1.9555317
# Epoch = 14, Step = 900, disc_loss = 0.52853465 , gen_loss = 4.1493797
# Epoch = 14, Step = 1000, disc_loss = 0.42036635 , gen_loss = 3.886508
# Epoch = 14, Step = 1100, disc_loss = 0.43902165 , gen_loss = 3.068172
# Epoch = 14, Step = 1200, disc_loss = 0.58134437 , gen_loss = 1.8383551
# Epoch = 14, Step = 1300, disc_loss = 0.4549983 , gen_loss = 2.4119673
# Epoch = 14, Step = 1400, disc_loss = 0.45741758 , gen_loss = 3.3858562
# Epoch = 14, Step = 1500, disc_loss = 0.3897323 , gen_loss = 3.562083
# Epoch = 14, Step = 1600, disc_loss = 0.53403807 , gen_loss = 2.174341
# Epoch = 14, Step = 1700, disc_loss = 0.4628779 , gen_loss = 2.6892924
# Epoch = 14, Step = 1800, disc_loss = 0.5272778 , gen_loss = 2.0344896
# Epoch = 14, Step = 1900, disc_loss = 0.39093965 , gen_loss = 3.160332
# Epoch = 14, Step = 2000, disc_loss = 0.42549407 , gen_loss = 2.6837437
# Epoch = 14, Step = 2100, disc_loss = 0.5956268 , gen_loss = 1.8637413
# Epoch = 14, Step = 2200, disc_loss = 0.42762634 , gen_loss = 2.660138
# Epoch = 14, Step = 2300, disc_loss = 0.5138652 , gen_loss = 2.0433593
# Epoch = 14, Step = 2400, disc_loss = 0.42506802 , gen_loss = 2.686242
# Epoch = 14, Step = 2500, disc_loss = 0.7298663 , gen_loss = 2.0305758
# Epoch = 14, Step = 2600, disc_loss = 0.8955761 , gen_loss = 1.2136263
# Epoch = 14, Step = 2700, disc_loss = 0.41921037 , gen_loss = 2.697553
# Epoch = 14, Step = 2800, disc_loss = 0.43890488 , gen_loss = 2.6054225
# Epoch = 14, Step = 2900, disc_loss = 0.59294033 , gen_loss = 1.6407068
# Epoch = 14, Step = 3000, disc_loss = 0.46174493 , gen_loss = 2.380604
# Epoch = 14, Step = 3100, disc_loss = 0.44842833 , gen_loss = 2.3959851
# Epoch = 15, Step = 0, disc_loss = 0.4041014 , gen_loss = 3.0242188
# Epoch = 15, Step = 100, disc_loss = 0.5230006 , gen_loss = 1.900912
# Epoch = 15, Step = 200, disc_loss = 0.46668035 , gen_loss = 3.2986972
# Epoch = 15, Step = 300, disc_loss = 0.41774714 , gen_loss = 2.8963325
# Epoch = 15, Step = 400, disc_loss = 0.64833665 , gen_loss = 1.6757915
# Epoch = 15, Step = 500, disc_loss = 0.4120869 , gen_loss = 2.7894232
# Epoch = 15, Step = 600, disc_loss = 0.45280397 , gen_loss = 2.3201919
# Epoch = 15, Step = 700, disc_loss = 0.40147048 , gen_loss = 3.9589417
# Epoch = 15, Step = 800, disc_loss = 0.50164235 , gen_loss = 2.0803835
# Epoch = 15, Step = 900, disc_loss = 0.4151608 , gen_loss = 2.8852596
# Epoch = 15, Step = 1000, disc_loss = 0.5463329 , gen_loss = 1.9274389
# Epoch = 15, Step = 1100, disc_loss = 0.5296906 , gen_loss = 2.0312953
# Epoch = 15, Step = 1200, disc_loss = 0.39556935 , gen_loss = 3.1951363
# Epoch = 15, Step = 1300, disc_loss = 0.38723013 , gen_loss = 3.4719508
# Epoch = 15, Step = 1400, disc_loss = 0.41541874 , gen_loss = 3.050068
# Epoch = 15, Step = 1500, disc_loss = 0.46001834 , gen_loss = 2.445601
# Epoch = 15, Step = 1600, disc_loss = 0.5843251 , gen_loss = 1.7667692
# Epoch = 15, Step = 1700, disc_loss = 0.456756 , gen_loss = 2.4338636
# Epoch = 15, Step = 1800, disc_loss = 1.7880082 , gen_loss = 0.63087124
# Epoch = 15, Step = 1900, disc_loss = 0.41467953 , gen_loss = 2.7570565
# Epoch = 15, Step = 2000, disc_loss = 0.45776132 , gen_loss = 3.3392348
# Epoch = 15, Step = 2100, disc_loss = 0.7021556 , gen_loss = 1.3342161
# Epoch = 15, Step = 2200, disc_loss = 0.4746381 , gen_loss = 2.269181
# Epoch = 15, Step = 2300, disc_loss = 0.575114 , gen_loss = 1.7236346
# Epoch = 15, Step = 2400, disc_loss = 0.5225936 , gen_loss = 1.9864305
# Epoch = 15, Step = 2500, disc_loss = 0.43122375 , gen_loss = 2.8679867
# Epoch = 15, Step = 2600, disc_loss = 0.5691956 , gen_loss = 1.9470148
# Epoch = 15, Step = 2700, disc_loss = 0.46385223 , gen_loss = 2.2384136
# Epoch = 15, Step = 2800, disc_loss = 0.4099347 , gen_loss = 3.0386586
# Epoch = 15, Step = 2900, disc_loss = 0.8457979 , gen_loss = 1.4766222
# Epoch = 15, Step = 3000, disc_loss = 0.4026731 , gen_loss = 3.281149
# Epoch = 15, Step = 3100, disc_loss = 0.4366299 , gen_loss = 2.6092677
# Epoch = 16, Step = 0, disc_loss = 0.5456824 , gen_loss = 3.0377738
# Epoch = 16, Step = 100, disc_loss = 0.42479736 , gen_loss = 2.8510385
# Epoch = 16, Step = 200, disc_loss = 0.55880105 , gen_loss = 3.5215366
# Epoch = 16, Step = 300, disc_loss = 0.41545907 , gen_loss = 3.7036438
# Epoch = 16, Step = 400, disc_loss = 0.6811209 , gen_loss = 1.4389831
# Epoch = 16, Step = 500, disc_loss = 0.48143533 , gen_loss = 2.2123241
# Epoch = 16, Step = 600, disc_loss = 0.48068768 , gen_loss = 3.2059088
# Epoch = 16, Step = 700, disc_loss = 0.65698695 , gen_loss = 1.5830777
# Epoch = 16, Step = 800, disc_loss = 0.5330776 , gen_loss = 2.0269928
# Epoch = 16, Step = 900, disc_loss = 0.40997165 , gen_loss = 2.8937993
# Epoch = 16, Step = 1000, disc_loss = 0.4222639 , gen_loss = 2.6617749
# Epoch = 16, Step = 1100, disc_loss = 1.0770128 , gen_loss = 0.94053125
# Epoch = 16, Step = 1200, disc_loss = 0.42543712 , gen_loss = 2.706366
# Epoch = 16, Step = 1300, disc_loss = 0.45149863 , gen_loss = 2.4888475
# Epoch = 16, Step = 1400, disc_loss = 0.47704655 , gen_loss = 2.1954398
# Epoch = 16, Step = 1500, disc_loss = 0.39042586 , gen_loss = 3.2180905
# Epoch = 16, Step = 1600, disc_loss = 1.0808654 , gen_loss = 1.0614313
# Epoch = 16, Step = 1700, disc_loss = 0.44735193 , gen_loss = 2.9538016
# Epoch = 16, Step = 1800, disc_loss = 0.79450715 , gen_loss = 1.3567048
# Epoch = 16, Step = 1900, disc_loss = 0.4455122 , gen_loss = 2.4367766
# Epoch = 16, Step = 2000, disc_loss = 0.401705 , gen_loss = 3.0687094
# Epoch = 16, Step = 2100, disc_loss = 0.5814458 , gen_loss = 1.840228
# Epoch = 16, Step = 2200, disc_loss = 0.5603502 , gen_loss = 2.0271616
# Epoch = 16, Step = 2300, disc_loss = 0.45011735 , gen_loss = 2.3703518
# Epoch = 16, Step = 2400, disc_loss = 0.56483895 , gen_loss = 1.78947
# Epoch = 16, Step = 2500, disc_loss = 0.41142088 , gen_loss = 3.0265503
# Epoch = 16, Step = 2600, disc_loss = 0.453211 , gen_loss = 2.4048588
# Epoch = 16, Step = 2700, disc_loss = 0.42856267 , gen_loss = 2.585709
# Epoch = 16, Step = 2800, disc_loss = 0.3819753 , gen_loss = 3.2906005
# Epoch = 16, Step = 2900, disc_loss = 0.50526613 , gen_loss = 2.0656748
# Epoch = 16, Step = 3000, disc_loss = 0.43158868 , gen_loss = 3.020107
# Epoch = 16, Step = 3100, disc_loss = 0.45967108 , gen_loss = 2.3758554
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_16/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 16  ###
#
#
# Epoch = 17, Step = 0, disc_loss = 0.5364679 , gen_loss = 1.8729439
# Epoch = 17, Step = 100, disc_loss = 0.4227089 , gen_loss = 2.628723
# Epoch = 17, Step = 200, disc_loss = 1.381484 , gen_loss = 0.7379892
# Epoch = 17, Step = 300, disc_loss = 0.41737658 , gen_loss = 2.7563837
# Epoch = 17, Step = 400, disc_loss = 0.43387118 , gen_loss = 2.6690648
# Epoch = 17, Step = 500, disc_loss = 0.47820285 , gen_loss = 2.3091836
# Epoch = 17, Step = 600, disc_loss = 0.42381144 , gen_loss = 3.3292508
# Epoch = 17, Step = 700, disc_loss = 0.41216758 , gen_loss = 3.1789322
# Epoch = 17, Step = 800, disc_loss = 0.5513756 , gen_loss = 1.9438362
# Epoch = 17, Step = 900, disc_loss = 0.424249 , gen_loss = 3.6961489
# Epoch = 17, Step = 1000, disc_loss = 0.42274362 , gen_loss = 2.689675
# Epoch = 17, Step = 1100, disc_loss = 0.49020386 , gen_loss = 3.5657709
# Epoch = 17, Step = 1200, disc_loss = 0.43392983 , gen_loss = 2.6063335
# Epoch = 17, Step = 1300, disc_loss = 0.39405274 , gen_loss = 3.096859
# Epoch = 17, Step = 1400, disc_loss = 0.6692047 , gen_loss = 4.5585756
# Epoch = 17, Step = 1500, disc_loss = 0.4536296 , gen_loss = 3.464525
# Epoch = 17, Step = 1600, disc_loss = 0.7900944 , gen_loss = 1.2781122
# Epoch = 17, Step = 1700, disc_loss = 0.4605661 , gen_loss = 2.592272
# Epoch = 17, Step = 1800, disc_loss = 0.45417204 , gen_loss = 2.5199409
# Epoch = 17, Step = 1900, disc_loss = 0.44089866 , gen_loss = 2.9985347
# Epoch = 17, Step = 2000, disc_loss = 0.46748388 , gen_loss = 2.247784
# Epoch = 17, Step = 2100, disc_loss = 0.40394682 , gen_loss = 2.979154
# Epoch = 17, Step = 2200, disc_loss = 0.41035157 , gen_loss = 2.808479
# Epoch = 17, Step = 2300, disc_loss = 0.46737 , gen_loss = 2.289713
# Epoch = 17, Step = 2400, disc_loss = 0.5409687 , gen_loss = 1.9861248
# Epoch = 17, Step = 2500, disc_loss = 0.59836346 , gen_loss = 1.7825807
# Epoch = 17, Step = 2600, disc_loss = 0.95055866 , gen_loss = 1.1887892
# Epoch = 17, Step = 2700, disc_loss = 0.5423552 , gen_loss = 1.991482
# Epoch = 17, Step = 2800, disc_loss = 0.40093613 , gen_loss = 2.9152758
# Epoch = 17, Step = 2900, disc_loss = 0.6279071 , gen_loss = 1.7920082
# Epoch = 17, Step = 3000, disc_loss = 0.40337548 , gen_loss = 2.9616103
# Epoch = 17, Step = 3100, disc_loss = 0.41425395 , gen_loss = 3.18107
# Epoch = 18, Step = 0, disc_loss = 0.5044227 , gen_loss = 2.0763292
# Epoch = 18, Step = 100, disc_loss = 0.41551995 , gen_loss = 2.9521356
# Epoch = 18, Step = 200, disc_loss = 0.48590803 , gen_loss = 2.6711855
# Epoch = 18, Step = 300, disc_loss = 0.40410858 , gen_loss = 3.065178
# Epoch = 18, Step = 400, disc_loss = 0.4700572 , gen_loss = 2.2851005
# Epoch = 18, Step = 500, disc_loss = 0.7572949 , gen_loss = 1.4013318
# Epoch = 18, Step = 600, disc_loss = 0.4204654 , gen_loss = 2.6752067
# Epoch = 18, Step = 700, disc_loss = 0.55071247 , gen_loss = 2.538941
# Epoch = 18, Step = 800, disc_loss = 0.6601411 , gen_loss = 1.6785123
# Epoch = 18, Step = 900, disc_loss = 0.43322882 , gen_loss = 2.6286876
# Epoch = 18, Step = 1000, disc_loss = 0.7242185 , gen_loss = 1.6568685
# Epoch = 18, Step = 1100, disc_loss = 1.1635816 , gen_loss = 0.8583492
# Epoch = 18, Step = 1200, disc_loss = 0.4400405 , gen_loss = 2.574472
# Epoch = 18, Step = 1300, disc_loss = 0.41965085 , gen_loss = 2.7655582
# Epoch = 18, Step = 1400, disc_loss = 0.43455502 , gen_loss = 2.4792824
# Epoch = 18, Step = 1500, disc_loss = 0.43685818 , gen_loss = 2.9895146
# Epoch = 18, Step = 1600, disc_loss = 0.40981954 , gen_loss = 2.8889093
# Epoch = 18, Step = 1700, disc_loss = 0.4818897 , gen_loss = 2.136385
# Epoch = 18, Step = 1800, disc_loss = 0.7379339 , gen_loss = 1.448756
# Epoch = 18, Step = 1900, disc_loss = 0.5098996 , gen_loss = 2.170619
# Epoch = 18, Step = 2000, disc_loss = 0.45452082 , gen_loss = 2.4263299
# Epoch = 18, Step = 2100, disc_loss = 0.5258932 , gen_loss = 2.0906997
# Epoch = 18, Step = 2200, disc_loss = 0.40162352 , gen_loss = 3.0678618
# Epoch = 18, Step = 2300, disc_loss = 0.4752415 , gen_loss = 2.1939244
# Epoch = 18, Step = 2400, disc_loss = 0.4293202 , gen_loss = 2.6142385
# Epoch = 18, Step = 2500, disc_loss = 0.43970025 , gen_loss = 3.3720775
# Epoch = 18, Step = 2600, disc_loss = 0.39320266 , gen_loss = 3.1114647
# Epoch = 18, Step = 2700, disc_loss = 0.46959057 , gen_loss = 2.320433
# Epoch = 18, Step = 2800, disc_loss = 0.97697204 , gen_loss = 0.9586469
# Epoch = 18, Step = 2900, disc_loss = 0.39148697 , gen_loss = 3.0599377
# Epoch = 18, Step = 3000, disc_loss = 0.4206474 , gen_loss = 2.8358135
# Epoch = 18, Step = 3100, disc_loss = 0.47105184 , gen_loss = 2.2773461
# Epoch = 19, Step = 0, disc_loss = 0.40712562 , gen_loss = 3.0051975
# Epoch = 19, Step = 100, disc_loss = 0.42536187 , gen_loss = 2.7241967
# Epoch = 19, Step = 200, disc_loss = 0.42428768 , gen_loss = 3.0340035
# Epoch = 19, Step = 300, disc_loss = 0.4235772 , gen_loss = 2.855996
# Epoch = 19, Step = 400, disc_loss = 0.42905313 , gen_loss = 2.7244103
# Epoch = 19, Step = 500, disc_loss = 0.42305344 , gen_loss = 2.618762
# Epoch = 19, Step = 600, disc_loss = 0.4113379 , gen_loss = 3.7244878
# Epoch = 19, Step = 700, disc_loss = 0.54515797 , gen_loss = 2.0015116
# Epoch = 19, Step = 800, disc_loss = 0.546667 , gen_loss = 1.9175273
# Epoch = 19, Step = 900, disc_loss = 0.46082693 , gen_loss = 2.31744
# Epoch = 19, Step = 1000, disc_loss = 0.4432865 , gen_loss = 2.6298592
# Epoch = 19, Step = 1100, disc_loss = 2.7029283 , gen_loss = 0.43167126
# Epoch = 19, Step = 1200, disc_loss = 0.43409324 , gen_loss = 2.688865
# Epoch = 19, Step = 1300, disc_loss = 0.44358099 , gen_loss = 2.4794488
# Epoch = 19, Step = 1400, disc_loss = 0.43727428 , gen_loss = 2.491421
# Epoch = 19, Step = 1500, disc_loss = 0.43477643 , gen_loss = 3.033092
# Epoch = 19, Step = 1600, disc_loss = 0.5531072 , gen_loss = 1.850695
# Epoch = 19, Step = 1700, disc_loss = 0.5791302 , gen_loss = 1.750379
# Epoch = 19, Step = 1800, disc_loss = 0.44526666 , gen_loss = 2.676305
# Epoch = 19, Step = 1900, disc_loss = 0.41205078 , gen_loss = 2.8531759
# Epoch = 19, Step = 2000, disc_loss = 0.3780129 , gen_loss = 3.3171
# Epoch = 19, Step = 2100, disc_loss = 0.41309518 , gen_loss = 2.8132617
# Epoch = 19, Step = 2200, disc_loss = 0.38802364 , gen_loss = 3.1838186
# Epoch = 19, Step = 2300, disc_loss = 0.41797757 , gen_loss = 3.1068366
# Epoch = 19, Step = 2400, disc_loss = 0.4051701 , gen_loss = 2.815918
# Epoch = 19, Step = 2500, disc_loss = 0.39944124 , gen_loss = 2.9325461
# Epoch = 19, Step = 2600, disc_loss = 0.6173153 , gen_loss = 1.9386725
# Epoch = 19, Step = 2700, disc_loss = 0.4443914 , gen_loss = 2.388947
# Epoch = 19, Step = 2800, disc_loss = 0.4326404 , gen_loss = 2.4538903
# Epoch = 19, Step = 2900, disc_loss = 0.4133588 , gen_loss = 2.7370353
# Epoch = 19, Step = 3000, disc_loss = 0.8199789 , gen_loss = 3.376252
# Epoch = 19, Step = 3100, disc_loss = 0.96402013 , gen_loss = 1.1213031
# Epoch = 20, Step = 0, disc_loss = 0.43100262 , gen_loss = 2.5722623
# Epoch = 20, Step = 100, disc_loss = 0.4174388 , gen_loss = 3.629468
# Epoch = 20, Step = 200, disc_loss = 0.41565537 , gen_loss = 3.059181
# Epoch = 20, Step = 300, disc_loss = 0.40871528 , gen_loss = 2.968704
# Epoch = 20, Step = 400, disc_loss = 0.5066964 , gen_loss = 2.2888055
# Epoch = 20, Step = 500, disc_loss = 0.4076111 , gen_loss = 2.8301828
# Epoch = 20, Step = 600, disc_loss = 0.47660753 , gen_loss = 3.6553013
# Epoch = 20, Step = 700, disc_loss = 0.42527846 , gen_loss = 3.1466095
# Epoch = 20, Step = 800, disc_loss = 0.45528972 , gen_loss = 2.540846
# Epoch = 20, Step = 900, disc_loss = 0.43124056 , gen_loss = 2.5206752
# Epoch = 20, Step = 1000, disc_loss = 0.82024664 , gen_loss = 1.406725
# Epoch = 20, Step = 1100, disc_loss = 0.377041 , gen_loss = 3.941691
# Epoch = 20, Step = 1200, disc_loss = 0.77823263 , gen_loss = 1.5812601
# Epoch = 20, Step = 1300, disc_loss = 0.73474216 , gen_loss = 1.3306324
# Epoch = 20, Step = 1400, disc_loss = 0.44560745 , gen_loss = 2.487648
# Epoch = 20, Step = 1500, disc_loss = 0.4910077 , gen_loss = 2.281
# Epoch = 20, Step = 1600, disc_loss = 0.56138116 , gen_loss = 2.0048475
# Epoch = 20, Step = 1700, disc_loss = 1.9658637 , gen_loss = 3.6395664
# Epoch = 20, Step = 1800, disc_loss = 0.5879114 , gen_loss = 1.7914054
# Epoch = 20, Step = 1900, disc_loss = 0.40675822 , gen_loss = 2.8307588
# Epoch = 20, Step = 2000, disc_loss = 0.39103812 , gen_loss = 3.5436726
# Epoch = 20, Step = 2100, disc_loss = 0.40091965 , gen_loss = 2.9660296
# Epoch = 20, Step = 2200, disc_loss = 0.4060986 , gen_loss = 3.7877364
# Epoch = 20, Step = 2300, disc_loss = 0.42025262 , gen_loss = 2.5781565
# Epoch = 20, Step = 2400, disc_loss = 0.52007735 , gen_loss = 2.114264
# Epoch = 20, Step = 2500, disc_loss = 0.42170113 , gen_loss = 2.6375616
# Epoch = 20, Step = 2600, disc_loss = 0.40364265 , gen_loss = 3.1445215
# Epoch = 20, Step = 2700, disc_loss = 0.72124106 , gen_loss = 1.4628669
# Epoch = 20, Step = 2800, disc_loss = 0.39743102 , gen_loss = 3.0560393
# Epoch = 20, Step = 2900, disc_loss = 0.7977522 , gen_loss = 1.8280773
# Epoch = 20, Step = 3000, disc_loss = 0.4815596 , gen_loss = 2.2233024
# Epoch = 20, Step = 3100, disc_loss = 0.74488294 , gen_loss = 1.497943
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_20/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 20  ###
#
#
# Epoch = 21, Step = 0, disc_loss = 1.0177612 , gen_loss = 1.0523723
# Epoch = 21, Step = 100, disc_loss = 0.3909204 , gen_loss = 3.5114048
# Epoch = 21, Step = 200, disc_loss = 0.40881 , gen_loss = 2.810852
# Epoch = 21, Step = 300, disc_loss = 0.40163076 , gen_loss = 3.1659675
# Epoch = 21, Step = 400, disc_loss = 0.574463 , gen_loss = 2.211064
# Epoch = 21, Step = 500, disc_loss = 0.39913082 , gen_loss = 3.024065
# Epoch = 21, Step = 600, disc_loss = 0.5236935 , gen_loss = 4.0982523
# Epoch = 21, Step = 700, disc_loss = 0.40708122 , gen_loss = 2.8884168
# Epoch = 21, Step = 800, disc_loss = 0.41152602 , gen_loss = 2.76992
# Epoch = 21, Step = 900, disc_loss = 1.9941043 , gen_loss = 5.723604
# Epoch = 21, Step = 1000, disc_loss = 0.415188 , gen_loss = 3.084958
# Epoch = 21, Step = 1100, disc_loss = 0.4456124 , gen_loss = 2.5298944
# Epoch = 21, Step = 1200, disc_loss = 0.38643843 , gen_loss = 3.3671207
# Epoch = 21, Step = 1300, disc_loss = 0.42623866 , gen_loss = 2.5692077
# Epoch = 21, Step = 1400, disc_loss = 0.5435717 , gen_loss = 1.9362209
# Epoch = 21, Step = 1500, disc_loss = 0.40734902 , gen_loss = 3.1319742
# Epoch = 21, Step = 1600, disc_loss = 0.48996133 , gen_loss = 2.6137285
# Epoch = 21, Step = 1700, disc_loss = 0.40196377 , gen_loss = 3.0326545
# Epoch = 21, Step = 1800, disc_loss = 0.37227327 , gen_loss = 5.070773
# Epoch = 21, Step = 1900, disc_loss = 0.5787556 , gen_loss = 1.7539492
# Epoch = 21, Step = 2000, disc_loss = 0.41480502 , gen_loss = 2.6848123
# Epoch = 21, Step = 2100, disc_loss = 0.41863012 , gen_loss = 2.664293
# Epoch = 21, Step = 2200, disc_loss = 0.43652546 , gen_loss = 2.446352
# Epoch = 21, Step = 2300, disc_loss = 0.3791844 , gen_loss = 3.5116172
# Epoch = 21, Step = 2400, disc_loss = 0.43401122 , gen_loss = 2.5536115
# Epoch = 21, Step = 2500, disc_loss = 0.419241 , gen_loss = 2.8383675
# Epoch = 21, Step = 2600, disc_loss = 0.8375826 , gen_loss = 1.1979641
# Epoch = 21, Step = 2700, disc_loss = 0.4861151 , gen_loss = 2.0564814
# Epoch = 21, Step = 2800, disc_loss = 0.41352022 , gen_loss = 2.7092533
# Epoch = 21, Step = 2900, disc_loss = 0.41441172 , gen_loss = 2.6502612
# Epoch = 21, Step = 3000, disc_loss = 0.44944707 , gen_loss = 2.4190152
# Epoch = 21, Step = 3100, disc_loss = 0.5381168 , gen_loss = 2.0888247
# Epoch = 22, Step = 0, disc_loss = 0.38256612 , gen_loss = 3.411762
# Epoch = 22, Step = 100, disc_loss = 1.1057671 , gen_loss = 1.2346306
# Epoch = 22, Step = 200, disc_loss = 0.39633015 , gen_loss = 3.050881
# Epoch = 22, Step = 300, disc_loss = 0.47255492 , gen_loss = 3.5057435
# Epoch = 22, Step = 400, disc_loss = 0.4788143 , gen_loss = 2.2985258
# Epoch = 22, Step = 500, disc_loss = 0.39852792 , gen_loss = 3.7083046
# Epoch = 22, Step = 600, disc_loss = 0.40495932 , gen_loss = 2.802981
# Epoch = 22, Step = 700, disc_loss = 0.45875767 , gen_loss = 3.570493
# Epoch = 22, Step = 800, disc_loss = 0.4145933 , gen_loss = 2.7327094
# Epoch = 22, Step = 900, disc_loss = 2.0676603 , gen_loss = 0.5539041
# Epoch = 22, Step = 1000, disc_loss = 0.39228857 , gen_loss = 3.3309684
# Epoch = 22, Step = 1100, disc_loss = 0.5619141 , gen_loss = 1.8829904
# Epoch = 22, Step = 1200, disc_loss = 0.407831 , gen_loss = 3.0015795
# Epoch = 22, Step = 1300, disc_loss = 0.3850773 , gen_loss = 3.4786448
# Epoch = 22, Step = 1400, disc_loss = 0.63375217 , gen_loss = 1.5927237
# Epoch = 22, Step = 1500, disc_loss = 0.47550416 , gen_loss = 2.8930507
# Epoch = 22, Step = 1600, disc_loss = 0.4521167 , gen_loss = 2.3846705
# Epoch = 22, Step = 1700, disc_loss = 0.4205728 , gen_loss = 2.6853347
# Epoch = 22, Step = 1800, disc_loss = 0.5183049 , gen_loss = 2.0378785
# Epoch = 22, Step = 1900, disc_loss = 0.45851383 , gen_loss = 2.4912682
# Epoch = 22, Step = 2000, disc_loss = 0.37917188 , gen_loss = 3.707055
# Epoch = 22, Step = 2100, disc_loss = 0.4479383 , gen_loss = 2.3044178
# Epoch = 22, Step = 2200, disc_loss = 0.38367254 , gen_loss = 3.1644619
# Epoch = 22, Step = 2300, disc_loss = 0.41432458 , gen_loss = 2.855231
# Epoch = 22, Step = 2400, disc_loss = 0.46958858 , gen_loss = 2.2959545
# Epoch = 22, Step = 2500, disc_loss = 0.41413495 , gen_loss = 2.732544
# Epoch = 22, Step = 2600, disc_loss = 0.5082717 , gen_loss = 2.2369664
# Epoch = 22, Step = 2700, disc_loss = 0.4322106 , gen_loss = 2.5140946
# Epoch = 22, Step = 2800, disc_loss = 0.41240042 , gen_loss = 2.7999454
# Epoch = 22, Step = 2900, disc_loss = 0.3974078 , gen_loss = 3.1250896
# Epoch = 22, Step = 3000, disc_loss = 0.43096846 , gen_loss = 2.586685
# Epoch = 22, Step = 3100, disc_loss = 0.5871671 , gen_loss = 2.0237856
# Epoch = 23, Step = 0, disc_loss = 0.4632702 , gen_loss = 3.812015
# Epoch = 23, Step = 100, disc_loss = 0.3899194 , gen_loss = 3.1307127
# Epoch = 23, Step = 200, disc_loss = 0.5566876 , gen_loss = 1.837578
# Epoch = 23, Step = 300, disc_loss = 0.42000866 , gen_loss = 2.8257067
# Epoch = 23, Step = 400, disc_loss = 0.38263226 , gen_loss = 3.649857
# Epoch = 23, Step = 500, disc_loss = 0.4554054 , gen_loss = 3.3731399
# Epoch = 23, Step = 600, disc_loss = 0.42482486 , gen_loss = 2.8328896
# Epoch = 23, Step = 700, disc_loss = 0.3713837 , gen_loss = 4.119764
# Epoch = 23, Step = 800, disc_loss = 0.41422176 , gen_loss = 2.716284
# Epoch = 23, Step = 900, disc_loss = 0.49578884 , gen_loss = 2.6010907
# Epoch = 23, Step = 1000, disc_loss = 0.56631637 , gen_loss = 1.9342995
# Epoch = 23, Step = 1100, disc_loss = 0.40793085 , gen_loss = 2.894239
# Epoch = 23, Step = 1200, disc_loss = 0.3855696 , gen_loss = 3.2747974
# Epoch = 23, Step = 1300, disc_loss = 0.3991998 , gen_loss = 3.2434561
# Epoch = 23, Step = 1400, disc_loss = 0.5610244 , gen_loss = 1.9455968
# Epoch = 23, Step = 1500, disc_loss = 0.41647822 , gen_loss = 3.476891
# Epoch = 23, Step = 1600, disc_loss = 0.5785972 , gen_loss = 2.0223083
# Epoch = 23, Step = 1700, disc_loss = 0.44936162 , gen_loss = 2.3619795
# Epoch = 23, Step = 1800, disc_loss = 0.48378497 , gen_loss = 2.2706206
# Epoch = 23, Step = 1900, disc_loss = 0.44328058 , gen_loss = 2.588788
# Epoch = 23, Step = 2000, disc_loss = 0.36419773 , gen_loss = 3.7612677
# Epoch = 23, Step = 2100, disc_loss = 0.41008455 , gen_loss = 2.8109393
# Epoch = 23, Step = 2200, disc_loss = 0.45161512 , gen_loss = 3.193869
# Epoch = 23, Step = 2300, disc_loss = 0.42286703 , gen_loss = 2.6215076
# Epoch = 23, Step = 2400, disc_loss = 0.4090626 , gen_loss = 2.946473
# Epoch = 23, Step = 2500, disc_loss = 0.39565742 , gen_loss = 3.0770607
# Epoch = 23, Step = 2600, disc_loss = 0.43835464 , gen_loss = 2.559475
# Epoch = 23, Step = 2700, disc_loss = 0.45131838 , gen_loss = 2.5177693
# Epoch = 23, Step = 2800, disc_loss = 0.40177274 , gen_loss = 3.007246
# Epoch = 23, Step = 2900, disc_loss = 0.49781054 , gen_loss = 2.0208874
# Epoch = 23, Step = 3000, disc_loss = 0.40294957 , gen_loss = 2.942809
# Epoch = 23, Step = 3100, disc_loss = 0.90115416 , gen_loss = 1.377893
# Epoch = 24, Step = 0, disc_loss = 0.44496548 , gen_loss = 3.6129737
# Epoch = 24, Step = 100, disc_loss = 0.39429846 , gen_loss = 3.1512995
# Epoch = 24, Step = 200, disc_loss = 0.9097691 , gen_loss = 1.1705588
# Epoch = 24, Step = 300, disc_loss = 0.3873009 , gen_loss = 3.4280415
# Epoch = 24, Step = 400, disc_loss = 0.4043077 , gen_loss = 2.8214402
# Epoch = 24, Step = 500, disc_loss = 0.41838706 , gen_loss = 2.991498
# Epoch = 24, Step = 600, disc_loss = 0.40532017 , gen_loss = 3.064949
# Epoch = 24, Step = 700, disc_loss = 0.3827938 , gen_loss = 3.5484476
# Epoch = 24, Step = 800, disc_loss = 0.57835054 , gen_loss = 1.663659
# Epoch = 24, Step = 900, disc_loss = 0.54560983 , gen_loss = 2.3113759
# Epoch = 24, Step = 1000, disc_loss = 0.3810972 , gen_loss = 3.4528637
# Epoch = 24, Step = 1100, disc_loss = 0.429747 , gen_loss = 2.5773437
# Epoch = 24, Step = 1200, disc_loss = 0.48497456 , gen_loss = 2.1149466
# Epoch = 24, Step = 1300, disc_loss = 0.39402002 , gen_loss = 3.2467048
# Epoch = 24, Step = 1400, disc_loss = 0.6142251 , gen_loss = 1.9243432
# Epoch = 24, Step = 1500, disc_loss = 0.4539479 , gen_loss = 2.3654282
# Epoch = 24, Step = 1600, disc_loss = 0.3955621 , gen_loss = 3.01082
# Epoch = 24, Step = 1700, disc_loss = 0.4710133 , gen_loss = 2.191979
# Epoch = 24, Step = 1800, disc_loss = 0.5422803 , gen_loss = 1.9528284
# Epoch = 24, Step = 1900, disc_loss = 0.7046399 , gen_loss = 1.8617265
# Epoch = 24, Step = 2000, disc_loss = 0.39311776 , gen_loss = 3.432822
# Epoch = 24, Step = 2100, disc_loss = 3.1837225 , gen_loss = 0.3647187
# Epoch = 24, Step = 2200, disc_loss = 0.79418784 , gen_loss = 1.7639539
# Epoch = 24, Step = 2300, disc_loss = 0.5092757 , gen_loss = 2.1305385
# Epoch = 24, Step = 2400, disc_loss = 0.42286235 , gen_loss = 2.6107552
# Epoch = 24, Step = 2500, disc_loss = 0.49262416 , gen_loss = 2.1671665
# Epoch = 24, Step = 2600, disc_loss = 0.43006456 , gen_loss = 2.5857546
# Epoch = 24, Step = 2700, disc_loss = 0.38678697 , gen_loss = 3.0562987
# Epoch = 24, Step = 2800, disc_loss = 0.75962067 , gen_loss = 5.0437093
# Epoch = 24, Step = 2900, disc_loss = 0.37399486 , gen_loss = 3.9048853
# Epoch = 24, Step = 3000, disc_loss = 0.7020874 , gen_loss = 1.3916657
# Epoch = 24, Step = 3100, disc_loss = 0.45591408 , gen_loss = 2.4848673
# INFO:tensorflow:/content/drive/My Drive/Colab Notebooks/GAN/Face Editing/DCGAN_saved_models/try_epoch_24/ is not in all_model_checkpoint_paths. Manually adding it.
#
#
# ### Model Weights Saved Epoch = 24  ###

# %%
len(disc_train_loss)
# Out:
# 800

# %%
len(gen_train_loss)
# Out:
# 800

# %%
from matplotlib import pyplot

# %%
pyplot.subplot(2, 1, 1)
pyplot.plot(disc_train_loss, label='d-loss')
pyplot.plot(gen_train_loss, label='g-loss')
pyplot.legend()
